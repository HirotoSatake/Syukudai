# %%
import pandas as pd

# %%
#1
df = pd.read_csv("syukudai2.csv")

# %%
#2
df
# Out:
#       name  age  score gender
# 0    Alice   20     88      F
# 1      Bob   22     75      M
# 2  Charlie   21     92      M
# 3    Diana   20     85      F

# %%
#3
df.shape
# Out:
# (4, 4)

# %%
#4
print(df.dtypes)
# Out:
# name      object
# age        int64
# score      int64
# gender    object
# dtype: object

# %%
#5
df["score"].mean()
# Out:
# np.float64(85.0)

# %%
#6
df.query("age >= 21")
# Out:
#       name  age  score gender
# 1      Bob   22     75      M
# 2  Charlie   21     92      M

# %%
#7
df.query("score >= 80")
# Out:
#       name  age  score gender
# 0    Alice   20     88      F
# 2  Charlie   21     92      M
# 3    Diana   20     85      F

# %%
#8
print(df.sort_values("score"))
# Out:
#       name  age  score gender rank
# 1      Bob   22     75      M    B
# 3    Diana   20     85      F    A
# 0    Alice   20     88      F    A
# 2  Charlie   21     92      M    A

# %%
df["rank"] = pd.cut(df["score"], bins=[0, 60, 70, 80, 100], labels=["D", "C", "B", "A"])

# %%
df
# Out:
#       name  age  score gender rank
# 0    Alice   20     88      F    A
# 1      Bob   22     75      M    B
# 2  Charlie   21     92      M    A
# 3    Diana   20     85      F    A
